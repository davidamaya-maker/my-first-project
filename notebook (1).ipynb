# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Hello David,**
#
# Thank you for carefully addressing all the feedback from previous review. I appreciate the attention to detail you've shown in improving each aspect - the project looks excellent now.
#
# Congratulations on your accomplishment! Your project has been accepted, marking another exciting milestone in your journey. The quality of your work demonstrates impressive growth, and I'm confident you'll continue to excel in future projects.
#
# Keep up the outstanding work! ✨

# %% [markdown]
# <div style="border:solid blue 2px; padding: 20px">
#
# **Hello David,**
#
# Congratulations on submitting your second Python practical project! 🎉
#
# You’re making fantastic progress, and each project you complete brings you one step closer to mastering the core skills of data analysis. Your dedication and effort are clearly reflected in your work — you should feel proud of this achievement!
#
# Keep up the great momentum — let’s dive into the project together.
#
# ---
#
# You’ll find specific notes throughout the project file, marked in green, yellow, or red.
# Here’s a quick guide to what each color means.
# **Note:** Please don’t remove or alter these comments — they help guide both your own revision process and any future reviews.
#
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer’s Comment</b>
#
# These highlight strong solutions and great ideas that you can apply to future projects.
# </div>
#
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer’s Comment</b>
#
# These point out areas where the project could be improved. Revisions aren't required, but making them will strengthen your work.
# </div>
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer’s Comment</b>
#
# These indicate issues that need to be addressed before the project can be accepted.
# </div>
#
# ---
#
# **Project Review Summary:**
#
# **✅ What Went Well:**
#
# - **Data Pre-Processing:** You showed a solid grasp of Python by applying appropriate techniques to clean and prepare the data. Great job!
#
# - **Code Quality:** Your code is well-structured and easy to follow — a great demonstration of both your technical ability and attention to clean, maintainable code.
#
# - **Data Visualization:** The charts you created answered the analysis questions clearly. They were thoughtfully designed and added strong value to your insights. Excellent work!
#
# **🔧 Areas for Improvement:**
#
# - Specific suggestions are marked directly in the notebook.
#
# ---
#
# Feel free to add your own comments, share thoughts on the changes you’ve made, or ask questions using the format below. Just copy and paste it into a Markdown cell:
#
# ```
#
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b></div>
# ```
#
# It will appear like this:
#
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b></div>
#
# ---
#
# Revisions are a normal and important part of the learning process, so don’t get discouraged! Take your time, review the feedback, and make the necessary updates. Once you're ready, resubmit the project — I’m confident you’ll do great.
#
# Every challenge is a chance to grow. You’ve got this! 🏄
#
# </div>

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️ Excellent introduction.
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
#
# A project title and introduction are essential to provide context and clarity to your work. Please ensure these elements are included.
#
# For the introduction, it would be most effective to cover the following:
#
# - A brief overview of the situation or problem being addressed;
# - A clear statement of the project's objective, outlining what you aim to achieve;
# - A description of the dataset(s) you'll be using, highlighting key attributes and any relevant details;
# - A brief plan or strategy detailing how you intend to reach your goal.
#
# </div>

# %% [markdown]
# ***David Amaya's Sprint 2 Project***
#
# **Brief Overview:**
#
# Instacart's success allows meaningful intergration of sourced data and applied analysis. This Sprint 2 project elucidates several Kaggle-sourced Instacart CSV files through python and imported tools and arrives at several insights. Some of these include: understanding the data itself (e.g. .info(), .describe(), etc.), quantifying and qualifying arguments and claims (e.g. "top 20", "busiest time of the day", value_counts(), .duplicated(), .isna(), etc.), along with other cross-matrix conclusions derived only through the creation of newly merged data frames (groupby.sum; merge(,on=), etc.) and other customization efforts. **The project's objective then is to supply insight for decision-making abilities from creative inquiry and data-processing through python, pandas, matplotlib_pyplot, and their respective syntax and its structures**.
#
#
# **Data Dictionary:**
#
# a. instacart_orders.csv: each row corresponds to one order on the Instacart app; (columns= *"order_id", "user_id", "order_number", "order_dow", "order_hour_of_day", "days_since_prior_order"*)
#
# b. products.csv: each row corresponds to a unique product that customers can buy; (columns= *"product_id", "product_name", "aisle_id", "department_id"*)
#
# c. order_products.csv: each row corresponds to one item placed in an order; (columns= *"order_id", "product_id", "add_to_cart_order", "reordered")
#
# d. aisles.csv: ID number that uniquely identifies each grocery aisle category and name of the aisle; (columns= "aisle_id", "aisle")
#
# e. departments.csv: ID number that uniquely identifies each grocery department category and name of the department; (columns= *"department_id", "department"*)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

orders = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
print(orders.info())
products = pd.read_csv('/datasets/products.csv', sep=';')
print(products.info())
aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
print(aisles
    
    .info())
departments = pd.read_csv('/datasets/departments.csv', sep = ';')
print(departments.info())
order_products = pd.read_csv('/datasets/order_products.csv', sep=';')
print(order_products.info(show_counts=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# ...

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
# To keep your notebook well-organized and easy to work with, it’s a good idea to import all necessary libraries in a **dedicated cell at the very beginning**. This structure has a few practical benefits:
#
# - You can easily see which libraries are being used in the project at a glance.
# - If you need to import an additional library later, you can do so without re-running earlier data-loading or preprocessing steps.
# - It helps other readers (or future you!) quickly set up the environment.
#
# ---
#
# Also, while using the `info()` method is a great start, it’s helpful to pair it with `head()` to take a quick look at the first few rows of data. This gives a better sense of how the dataset is structured and what the actual values look like.
#
# </div>

# %% [markdown]
# ***#imported datasets & printed info; ensured all ID columns are listed at int64***
#
# The Instacart data has been reviewed for brief glance obversation of files and their substance. This includes:
# 1. Column Names: All column names are coherent enough for easy reference. No misspellings or natural anomolies could be discovered.
# 2. Data types: int64, float64, object
# 3. Missing values: includes: orders["days_since_prior_order"], products["product_name"], and order_products["add_to_cart_order"]

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️
#
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
#
# After you've studied the data don't forget to write a brief summary of your observations.
#
# In your observations, it is recommended to include the following:
#
# - **Column names** – Indicate if any columns require renaming.
# - **Data types** – Verify whether the current data types are optimal or need modification.
# - **Missing values** – If the non-null count is less than the total number of entries, this indicates missing values.
#
# You can easily obtain this information from the `head()` and `info()` methods on your dataset.

# %% [markdown]
# ## Find and remove duplicate values (and describe why you make your choices)

# %% [markdown]
# ### `orders` data frame

# %%
# Check for duplicated orders
orders_duplicated = orders[orders.duplicated()]

print(orders_duplicated)


#orders = orders.drop_duplicates()
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️
#
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Please make sure to follow only the instructions described in the cell.
# For example, in this case, you were only asked to check for duplicates — not to remove them.
# At this stage, you're only beginning to explore duplicates, so removing them is not required yet.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️ Thanks for your question — I see now what caused the confusion. The subtitle "Find and remove duplicate values (and describe why you make your choices)" is indeed a section header. And yes, in this section your task is to both find and remove duplicates — but not immediately.
#
# First, before removing duplicates, we need to **check** whether they are true duplicates. Sometimes rows can look identical but are not true duplicates from a data integrity perspective (though ideally, data systems should be designed to differentiate such cases).
#
# So in this case:
# - In the first cell of the section (cell 2), you need to **find** the duplicates.
# - Then, **study** them (cell 3).
# - Only after that, in cell 4, according to the instructions, should you **remove** them.
#
# If you remove duplicates immediately, you won't be able to analyze them properly, which is an important part of the task.
#
# Hope this clears up the confusion!
#
#
# <div class="alert alert-info"; style="border-left: 7px solid blue">
# <b>Student’s Comment</b>Hello! I am a little confused by the subtitle which states to "find and remove" duplicates but your comment suggests that I do not remove the duplicates. Can you please clarify to help my understanding?

# %% [markdown]
# I created a variable to house where the df for checked duplicates would go to. I used the .duplicated() method to render these duplictaed rows. This is followed by calling .drop_duplicates() to remove duplicated rows on the original df.

# %%
# Check for all orders placed Wednesday at 2:00 AM
wednesday_2am_orders = orders[
    (orders['order_dow'] == 3) &
    (orders['order_hour_of_day'] == 2)
]

print(wednesday_2am_orders)
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 4838     2766110   162084            41          3                  2
# 5156     2190225   138285            18          3                  2
# 15506     553049    58599            13          3                  2
# 18420     382357   120200            19          3                  2
# 24691     690242    77357             2          3                  2
# ...          ...      ...           ...        ...                ...
# 457013   3384021    14881             6          3                  2
# 458816    910166   164782            18          3                  2
# 459635   1680532   106435             6          3                  2
# 468324    222962    54979            59          3                  2
# 477526   2592344    46860            38          3                  2
#
#         days_since_prior_order
# 4838                      16.0
# 5156                      11.0
# ...

# %% [markdown]
# For [22], we assigned a boolean mask to the variable wednesday_2am_orders where the 'order_dow' == 3 (i.e. Wednesday) AND 'order_hour_of_the_day' == 2 (i.e. 2 AM). We are returned 106 rows and 6 columns.

# %%
# Remove duplicate orders
orders = orders.drop_duplicates(keep='first')

# %% [markdown]
# Here, we removed the duplicated rows & kept the first iteration of each duplicated row.

# %%
# Double check for duplicate rows
print(orders.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Double checked for duplicates using .duplicated().sum()

# %%
# Double check for duplicate order IDs only
print(orders['order_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# There are no duplicated cells in 'order_id'

# %% [markdown]
# ### `products` data frame

# %%
# Check for fully duplicate rows
products_duplicated = products.duplicated().sum()

print(products_duplicated)

print(products.info())
# Out:
# 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None

# %% [markdown]
# Called .duplicated().sum() on products to check for duplicate rows.

# %%
# Check for just duplicate product IDs
print(products['product_id'].duplicated().sum())
# Out:
# 0

# %% [markdown]
# Called duplicated().sum() on 'product_id' to check for duplicate cells.

# %%
# Check for just duplicate product names (convert names to lowercase to compare better)

products['product_name'] = products['product_name'].str.lower()

duplicated_product_name = products[products['product_name'].duplicated()]

print(duplicated_product_name.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1361 entries, 71 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     1361 non-null   int64
#  1   product_name   104 non-null    object
#  2   aisle_id       1361 non-null   int64
#  3   department_id  1361 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 53.2+ KB
# None

# %% [markdown]
# Here, we created a df that houses duplicated 'product_name' values. We printed it's .info() to discover 1361 rows of duplicated values.

# %%
# Check for duplicate product names that aren't missing
import pandas as pd
dupes_notna_notmissing = (
    products['product_name'].notna().sum()
    &
    (products['product_name'].str.strip() != '')
)

# %%
#Added by reviewer

products[(products['product_name'].notna()) & (products['product_name'].str.strip().duplicated())]
# Out:
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  biotin 1000 mcg        47
# 5455         5456                 green tea with ginseng and honey        96
# 5558         5559                           cream of mushroom soup        69
# 7558         7559                        cinnamon rolls with icing       105
# 9037         9038                           american cheese slices        21
# ...           ...                                              ...       ...
# 49689       49690                    high performance energy drink        64
# 49690       49691                    original pancake & waffle mix       130
# 49691       49692  organic instant oatmeal light maple brown sugar       130
# 49692       49693                           spring water body wash       127
# 49693       49694                          burrito- steak & cheese        38
#
#        department_id
# 2058              11
# ...

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 2</b>
#
# Refer to the example above to see how these rows should be displayed. Previously, you checked only for duplicated product names and identified 1,361 rows. However, missing product names are also treated as duplicates. With the updated condition, we exclude missing values and focus only on actual duplicated product names, which yields only 104 rows.
#
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Here you need to apply two conditions simultaneously:
# 1. The product name is **not** null.
# 2. The product name is **missing** (i.e., an empty string or whitespace).
#
# Both conditions should be included to ensure accurate filtering.

# %% [markdown]
#                                 ***
# Here, we have counted the number of values within the column 'product_name' that are NOT na. Additionally, we relied on .str.strip() and Boolean logic to locate all non-null cells with and empty string after stripping the cells.
#
#                                 ***

# %% [markdown]
# ### `departments` data frame

# %%
print(f'Total number of duplicate rows: {departments.duplicated().sum()}')
# Out:
# Total number of duplicate rows: 0

# %% [markdown]
# Here, we checked for duplicates!

# %%
departments['department'] = departments['department'].str.lower()

departments_sorted = departments.sort_values(by='department', inplace =False)

departments_sorted.index.name = 'former_index'

print(departments_sorted.reset_index(drop=False).head(20))
# Out:
#     former_index  department_id       department
# 0              4              5          alcohol
# 1             17             18           babies
# 2              2              3           bakery
# 3              6              7        beverages
# 4             13             14        breakfast
# 5              9             10             bulk
# 6             14             15     canned goods
# 7             15             16       dairy eggs
# 8             19             20             deli
# 9              8              9  dry goods pasta
# 10             0              1           frozen
# 11            16             17        household
# 12             5              6    international
# 13            11             12     meat seafood
# 14            20             21          missing
# 15             1              2            other
# 16            12             13           pantry
# 17            10             11    personal care
# ...

# %% [markdown]
# Here, we sorted the departments df by ascension via 'department' column. We reset the index as well, supplying the "former index" (i.e. 'former_index') next to the new index.

# %% [markdown]
# ### `aisles` data frame

# %%
aisles_duplicated = aisles.duplicated().sum()

print(aisles_duplicated)
# Out:
# 0

# %% [markdown]
# Checked aisles for duplicates

# %%
aisles.sort_values(by='aisle',
                           ascending = True,
                           inplace = True,)

aisles.index.name = 'former_index'


aisles.reset_index(inplace= True,
                  drop= False)


print(aisles)
# Out:
#      former_index  aisle_id                          aisle
# 0             100       101         air fresheners candles
# 1              65        66                    asian foods
# 2              81        82               baby accessories
# 3             101       102            baby bath body care
# 4              91        92              baby food formula
# ..            ...       ...                            ...
# 129            59        60              trash bags liners
# 130            46        47           vitamins supplements
# 131           114       115  water seltzer sparkling water
# 132            61        62                    white wines
# 133           119       120                         yogurt
#
# [134 rows x 3 columns]

# %% [markdown]
# Here, we refined aisles to sort the df by sorting 'aisle' by ascension. We then reset the index after renaming it.

# %% [markdown]
# ### `order_products` data frame

# %%
# Check for fullly duplicate rows
print(order_products.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Here, we printed how many fully duplicated rows there are in df order_products. The result rendered is 0, meaning there are no duplicates in order_products.

# %%
# Double check for any other tricky duplicates
order_id_duplicated = order_products['order_id'].duplicated().sum()
print(f'Number of duplicates in \'order_id\' : {order_id_duplicated}')

product_id_duplicated = order_products['product_id'].duplicated().sum()
print(f'Number of duplicates in \'product_id\' : {order_id_duplicated}')
# Out:
# Number of duplicates in 'order_id' : 4094961
# Number of duplicates in 'product_id' : 4094961

# %% [markdown]
# Here, we checked for duplicates withing the 'order_id' column and the 'product_id' column.

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
# When checking for duplicates, we shouldn't only look for full duplicate rows, but also check whether combinations of values that are supposed to be unique are repeated.
#
# In this case, for example, there should be no repetition of the `order_id` + `product_id` pair.
#
# To check for such duplicates, you can simply use:
#
# `order_products[order_products.duplicated(subset=['order_id', 'product_id'])]`
#
# or
#
# `order_products.duplicated(subset=['order_id', 'product_id']).sum()`

# %% [markdown]
# ## Find and remove missing values

# %% [markdown]
# ### `products` data frame

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️
#
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Let's start by checking the overall number of missing values in the `products` dataframe.

# %%
# Are all of the missing product names associated with aisle ID 100?

#Added lines of code to complete Reviewer's comment above follows:
missing_product_names = products[products['product_name'].isna()]
print('Overall number of missing values in the products dataframe:', products['product_name'].isna().sum())
#End 'Added lines'
product_aisle_100 = (missing_product_names['aisle_id'] == 100).sum()

product_aisle_not_100 = (missing_product_names['aisle_id'] != 100).sum()

print(f'Total number of aisle 100 products: {product_aisle_100}')
print(f'Total number of non-aisle 100 products: {product_aisle_not_100}')
print("ALL of the missing product names ARE associated with aisle 100")
# Out:
# Overall number of missing values in the products dataframe: 1258
# Total number of aisle 100 products: 1258
# Total number of non-aisle 100 products: 0
# ALL of the missing product names ARE associated with aisle 100

# %% [markdown]
# Here, we used Boolean logic to discern the total number of .isna() values within products['product_name'] and how they relate to 'aisle_id' in regard to the value of 100. We find out, as demonstrated through the f-strings, that they are all in fact associated with aisle 100.

# %%
# Are all of the missing product names associated with department ID 21?
department_id_21 = (missing_product_names['department_id'] == 21).sum()
department_id_not_21 = (missing_product_names['department_id'] != 21).sum()

print(f'Total where department_id IS 21: {department_id_21}')
print(f'Total where department_id IS NOT 21: {department_id_not_21}')
print("ALL of the missing product names ARE associated with department 21")
# Out:
# Total where department_id IS 21: 1258
# Total where department_id IS NOT 21: 0
# ALL of the missing product names ARE associated with department 21

# %% [markdown]
# Here, we recycled the missing_product_names variable to similarly rely on Boolean logic to deduct values for department_id equating and NOT equating to 21. We discover that all products with missing names are associated with department 21

# %%
# What is this ailse and department?
aisle_100_name = aisles[aisles['aisle_id']==100]['aisle'].iloc[0]

dept_21_name = departments[departments['department_id']==21]['department'].iloc[0]

print(f"""Aisle 100 Name: {aisle_100_name}
Department 21 Name: {dept_21_name}""")
# Out:
# Aisle 100 Name: missing
# Department 21 Name: missing

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️
#
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Yes, the instruction is vague.
# To answer this question correctly, you need to look up the name of aisle `100` in the **aisles** dataframe and the name of department `21` in the **departments** dataframe.

# %%
# Fill missing product names with 'Unknown'
products['product_name'].fillna('Unknown', inplace=True)

print(products['product_name'].isna().sum())
# Out:
# 0

# %% [markdown]
# Here, I used the .fillna() method to inplace fill null values with 'Unknown'. I double-checked for null values counting .isna() values; we were retured a count of 0 so all null values have been replaced!

# %% [markdown]
# ### `orders` data frame

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️
#
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Let's first check whether there are any missing values in the `orders` dataframe at all.

# %%
# Are there any missing values where it's not a customer's first order?
#Begin added lines from Reviewer's comment, v.1
missing_orders = orders.isna().sum()
print(f"""
Total number of missing values in orders dataframe: 

{missing_orders}""")
#End added lines


return_customer = (orders[orders['order_number'] >= 2])

print(f"""

Below is the total number of missing values from return_customer dataframe per 
column:

{return_customer.isna().sum()}""")
# Out:
# Total number of missing values in orders dataframe:
#
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64
#
#
# Below is the total number of missing values from return_customer dataframe per
# column:
#
# order_id                  0
# user_id                   0
# order_number              0
# order_dow                 0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %% [markdown]
# Above, I relied on Boolean logic to create a variable where their order number is 2 or higher (i.e. NOT their first order). This is followed with a double check of .isna() to check for missing values presented in .sum() format.
#
# Additionally, I updated this code to show missing values in the orders dataframe.

# %% [markdown]
# ### `order_products` data frame

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Also, please check for missing values in the `order_products` dataframe.

# %%
#What are the min and max values in this column?
missing_order_products = order_products.isna().sum()

print(f"""
Total number of missing values in the order_products dataframe per column:

{missing_order_products}

""")

print("""
The min and max values of all aolumns for this data frame 
are presented through the describe() method; please consider this 
as specific column is not referenced.

Also, please note we first checked for missing values in the
order_products dataframe. This ensures calculations like Min and Max
are not skewed(?)

""")

print(order_products.describe())
# Out:
# Total number of missing values in the order_products dataframe per column:
#
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64
#
#
#
# The min and max values of all aolumns for this data frame
# are presented through the describe() method; please consider this
# as specific column is not referenced.
#
# Also, please note we first checked for missing values in the
# order_products dataframe. This ensures calculations like Min and Max
# are not skewed(?)
#
#
#            order_id    product_id  add_to_cart_order     reordered
# count  4.545007e+06  4.545007e+06       4.544171e+06  4.545007e+06
# mean   1.711166e+06  2.558084e+04       8.351669e+00  5.905025e-01
# std    9.850955e+05  1.409552e+04       7.080368e+00  4.917411e-01
# min    4.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.608170e+05  1.353500e+04       3.000000e+00  0.000000e+00
# ...

# %% [markdown]
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 2</b>
#
# Please note that you don’t need to use `print()` to display comment text. It’s more common in notebooks to use Markdown cells for comments. Code cells should contain only brief comments specifically related to the code.
#
# To change a cell type to Markdown, use the top navigation bar: create a new cell with the **+** button, then select the cell and choose “Markdown” from the dropdown menu where it currently says “Code.”
#
# </div>

# %%
# Save all order IDs with at least one missing value in 'add_to_cart_order'
add_to_cart_order_empty = order_products[order_products['add_to_cart_order'].isna()]

order_ids_for_empty_addtocart = add_to_cart_order_empty['order_id']

print(order_ids_for_empty_addtocart.value_counts())
# Out:
# 61355      63
# 3308010    51
# 2136777    44
# 171934     40
# 1959075    34
#            ..
# 2652650     1
# 2729254     1
# 2621907     1
# 888470      1
# 1677118     1
# Name: order_id, Length: 70, dtype: int64

# %%
# Do all orders with missing values have more than 64 products?
incomplete_cart_orders = order_products.loc[
    order_products['add_to_cart_order'].isna(),
    'order_id'
].unique()

print(f"""
Total number of orders with NaN in cart: {len(incomplete_cart_orders)}
""")

incomplete_cart_total_products = order_products[
    order_products['order_id'].isin(incomplete_cart_orders)
    ]

order_id_and_total_products = incomplete_cart_total_products['order_id'].value_counts()

print(f"""
NaN in cart AND order_id total products: 

{order_id_and_total_products}
"""
    )

print(f"""
Below, we use .describe() to find the min and max of cell values, 
particularly that of the total value count for each order_id

{order_id_and_total_products.describe()}


What this tells us that for every order_id with at least 1 NaN in 
add_to_cart_order, when grouped to find total number of products 
added to cart order of those order with at least 1 NaN, all orders 
are at least 65 (i.e. Min in .describe()""")
# Out:
# Total number of orders with NaN in cart: 70
#
#
# NaN in cart AND order_id total products:
#
# 61355      127
# 3308010    115
# 2136777    108
# 171934     104
# 1959075     98
#           ...
# 747668      65
# 2170451     65
# 2729254     65
# 2652650     65
# 9310        65
# Name: order_id, Length: 70, dtype: int64
#
#
# Below, we use .describe() to find the min and max of cell values,
# particularly that of the total value count for each order_id
#
# count     70.000000
# mean      75.942857
# std       12.898585
# min       65.000000
# 25%       67.000000
# 50%       71.000000
# 75%       78.000000
# max      127.000000
# Name: order_id, dtype: float64
#
#
# What this tells us that for every order_id with at least 1 NaN in
# add_to_cart_order, when grouped to find total number of products
# added to cart order of those order with at least 1 NaN, all orders
# are at least 65 (i.e. Min in .describe()

# %% [markdown]
# <div class="alert alert-success" style="border-left: 7px solid green">
# <b>✅ Reviewer's Comment, v. 2</b>
#
# Great job on the analysis! We can see that all orders with missing values contain more than 64 products.
#
# Previously, we observed that the maximum add-to-cart order number was 64 . This suggests that there might be a technical issue with assigning add-to-cart order numbers when items are added beyond this limit, which could explain the missing values.
#
# <div class="alert alert-danger" style="border-left: 7px solid red">
# <b>⛔️ Reviewer's Comment, v. 1</b>
#
# Currently, you are checking the size of missing values in each order, but you need to check the size of complete orders instead.
#
# To answer the question, follow these steps:
#
# 1. Save the IDs of orders with missing `add_to_cart_order` values to a list (this step is already done).
# 2. Select all the entries corresponding to these order IDs into a separate dataframe.
# 3. Group this new dataframe by order ID and check the sizes of these groups to find the minimum size.
#
# Could you please try implementing this?
#
# </div>

# %% [markdown]
# 1. We isolated all order_ids with missing values in the add_to_cart_order column using .isna() and .loc(). Then, we used .unique() to extract a clean list of distinct order_ids affected by this issue.
#
# 2. With this list of affected order_ids, we accessed the full order_products DataFrame to retrieve all rows (i.e., all products) associated with those carts. This allowed us to assess the complete size of each order, not just the products with missing values.
#
# 3. We used .isin() to filter the full dataset and create a new DataFrame (incomplete_cart_total_products) containing only the orders identified in Step 1.
#
# 4. We used .value_counts() on the order_id column to count how many products were included in each of these affected carts. This gave us the total number of products per incomplete order.
#
# 5. Finally, we used .describe() to analyze the product counts. The minimum cart size was found to be 65, meaning every order with at least one NaN in add_to_cart_order contained more than 64 products.

# %%
# Replace missing values with 999 and convert column to integer type
order_products['add_to_cart_order'] = order_products['add_to_cart_order'].fillna(999).astype(int)

# %% [markdown]
# Here, we used .fillna() and .astype(int) to fulfill the requirements of the task.

# %% [markdown]
# <div class="alert alert-success" style="border-left: 7px solid green">
# <b>✅ Reviewer's Comment, v. 1</b>
#
# Overall, you've done a great job in this section — you carefully studied the missing values and duplicates and applied the necessary cleaning steps, which are essential for accurate analysis in the following stages.
#
# Well done! You've completed all the required checks and data preprocessing.
# </div>

# %% [markdown]
# # [A] Easy (must complete all to pass)

# %% [markdown]
# ### [A1] Verify that the `'order_hour_of_day'` and `'order_dow'` values in the `orders` tables are sensible (i.e. `'order_hour_of_day'` ranges from 0 to 23 and `'order_dow'` ranges from 0 to 6)

# %%
print(orders['order_hour_of_day'].min(), orders['order_hour_of_day'].max())

print(orders['order_dow'].min(), orders['order_dow'].max())
# Out:
# 0 23
# 0 6

# %% [markdown]
# Printing the minimum and maximum values ensures ranges are indeed 0-23 for 'order_hour_of_day' and 0-6 'order_dow'!

# %% [markdown]
# ### [A2] What time of day do people shop for groceries?

# %%
orders_per_hour = orders['order_hour_of_day'].value_counts()

plt.figure(figsize=(12,6))
plt.bar(orders_per_hour.index, orders_per_hour.values, color = 'skyblue')
plt.title('Order Numbers by Hour of the Day')
plt.xlabel('Hour of the Day (0 = 12 AM')
plt.ylabel('Number or Orders')
plt.xticks(range(0,24))


plt.show()

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green"> <b>✅ Reviewer’s Comment, v. 2</b>
#
# Great job! You've created excellent charts with all the required elements, including a clear title, labeled axes, and appropriate scales. You've also drawn accurate conclusions from it.
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# In this section — as well as in Sections A3 and A4 — you need to create plots to visualize the data and support your answers.
# This requirement is clearly stated in the project brief.
# Please make sure to include the appropriate charts.

# %% [markdown]
# Using .value_counts(), we are able to see in descending order the most popular order times, 10, 11, and 15 being the most popular hours.
#
# Additionally, we used plt to create a bar chart that shows total number of orders by hour of the day. The bar chart illustrates that most people order between 9 and 16 (4 PM)). The bar is left-skewed– the least amount of customers order between the hours of 0 - 5. Most ordered at hours 7 - 20.

# %% [markdown]
# ### [A3] What day of the week do people shop for groceries?

# %%
dow_orders = orders['order_dow'].value_counts().sort_index()

plt.figure(figsize=(12,6))
plt.bar(dow_orders.index, dow_orders.values, color='seagreen')
plt.title('Number of Orders by Day of the Week')
plt.xlabel('Day of the Week (0 = Sunday)')
plt.ylabel('Number of Orders')
plt.show()

print("""
There is a noticable range between the Max and Min of the order distribution of about 2,000
orders between Sunday (Max) and Thursday (Min). The chart is right-skewed; there is a slight 
surge between Thursday and Friday.
""")
# Out:
# There is a noticable range between the Max and Min of the order distribution of about 2,000
# orders between Sunday (Max) and Thursday (Min). The chart is right-skewed; there is a slight
# surge between Thursday and Friday.

# %% [markdown]
# Similarly, we used .value_counts() to discern that Sunday ('0'), Monday ('1'), and Tuesday ('2') are the top 3 most popular order days.
#
# This is best illustrated using the barchart created above.

# %% [markdown]
# ### [A4] How long do people wait until placing another order?

# %%
#remove empty cells from 'days_since_prior_order'
valid_days_since_prior_order = orders['days_since_prior_order'].dropna()

plt.figure(figsize=(12,6))
plt.hist(valid_days_since_prior_order, bins = 32, edgecolor='black', color='seagreen')

plt.title('Number of Days Between Orders')
plt.xlabel('Number of Days Since Previous Order')
plt.ylabel('Number of Orders')
plt.xticks(range(0,31))

plt.show()

print(valid_days_since_prior_order.describe())

print(valid_days_since_prior_order.value_counts())
# Out:
# count    450135.000000
# mean         11.101814
# std           9.190004
# min           0.000000
# 25%           4.000000
# 50%           7.000000
# 75%          15.000000
# max          30.000000
# Name: days_since_prior_order, dtype: float64
# 30.0    51337
# 7.0     44577
# 6.0     33930
# 4.0     31006
# 3.0     30224
# 5.0     30096
# 2.0     27138
# 8.0     25361
# 1.0     20179
# 9.0     16753
# 14.0    13992
# 10.0    13309
# 13.0    11737
# 11.0    11467
# 12.0    10658
# 0.0      9589
# 15.0     9416
# 16.0     6587
# 21.0     6448
# 17.0     5498
# 20.0     5302
# 18.0     4971
# 19.0     4939
# 22.0     4514
# 28.0     3745
# 23.0     3337
# 24.0     3015
# 27.0     2986
# 25.0     2711
# 29.0     2673
# 26.0     2640
# Name: days_since_prior_order, dtype: int64

# %% [markdown]
# Above, I created a histogram for the distribution of number of days passed since last order.
#
# I also used the .describe() method to extract the mean and other relevant infromation to answer the question. For significant processing, I removed the empty cells within the 'days_since_prior_order' column.
#
# Then, we discover the average/mean wait-time is about 11 days, while the 50 percentile lands at 7 days.
#
# We also used .value_counts() to assess what day occurs the most: the top 3 (respectively) are 30, 7, and 6.

# %% [markdown]
# # [B] Medium (must complete all to pass)

# %% [markdown]
# ### [B1] Is there a difference in `'order_hour_of_day'` distributions on Wednesdays and Saturdays? Plot the histograms for both days and describe the differences that you see.

# %%
wednesday_orders = (orders[orders['order_dow'] == 3])

saturday_orders = (orders[orders['order_dow'] == 6])

plt.figure(figsize=(10,5))

plt.hist(wednesday_orders['order_hour_of_day'], 
         bins = 24, 
         alpha = 0.95,
        label = 'Wednesday',
        edgecolor = 'black')

plt.hist(saturday_orders['order_hour_of_day'], 
         bins = 24, 
         alpha = 0.65,
        label = 'Saturday',
        edgecolor = 'black')

plt.xlabel('Hour of Day')
plt.ylabel('Number of Orders')
plt.title('Number of Orders per Hour of the Day: Wednesday vs Saturday')
plt.legend()
plt.xticks(range(0,24))


plt.show()


print("""
The distribution of orders per hour of the day are similarly correlated but 
nonetheless exhibit discrepancies. The discrepencies are illustrated in the 
histogram through the alpha/transparency of the colors identified in the legend.
Where blue is the apex of the bin, Wednesday had more orders for the hour indicated 
(e.g. 7, 9, 10). Where orange is the apex of the bin, Saturday is day with more
orders. 

The correelation is positive, and there is an ascending pattern between hours of
day beginning at hour 5 and concluding around hour 10. 

In both days, peak hours are between 9 and 17 (5 PM). 

The differences between both days are nuanced except for hours 11 through 14, 
where we see a transparent gap indicating a larger than normal discrepancy. 
""")
# Out:
# The distribution of orders per hour of the day are similarly correlated but
# nonetheless exhibit discrepancies. The discrepencies are illustrated in the
# histogram through the alpha/transparency of the colors identified in the legend.
# Where blue is the apex of the bin, Wednesday had more orders for the hour indicated
# (e.g. 7, 9, 10). Where orange is the apex of the bin, Saturday is day with more
# orders.
#
# The correelation is positive, and there is an ascending pattern between hours of
# day beginning at hour 5 and concluding around hour 10.
#
# In both days, peak hours are between 9 and 17 (5 PM).
#
# The differences between both days are nuanced except for hours 11 through 14,
# where we see a transparent gap indicating a larger than normal discrepancy.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️
#
#
#
#
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
# You should avoid re-importing libraries throughout the project.
# It's best practice to import all necessary libraries at the very beginning.
# Then, simply run the notebook from the start — all libraries will be available as needed.

# %% [markdown]
# To create the requested histogram, ***I imported pandas and matplotlib.pyplot as plt.*** To feed our histogram relevant data re: order_hour_of_day for Wednesday and Saturday, we extracted a df from orders that is filtered to provide only rows with their respective 'order_dow' (i.e. Wednesday and Saturday).
# ***plt.figure(figsize=(10,5))*** establishes the histogram size.
#
# ***plt.hist(wednesday_orders['order_hour_of_day'], bins=24, alpha=0.95, label='Wednesday', edgecolor='black')***
#
# ***plt.hist(saturday_orders['order_hour_of_day'], bins=24, alpha=0.65, label='Saturday', edgecolor='black')***
#
# – these two ***plt.hist()*** pull into the plt the two dfs' created for Wednesday and Saturday. 24 ***bins*** for 24 hours. ***alphas'*** set for visual clarity. ***labels*** provide clarity for ***legend()***. ***edgecolor*** to silhouette the bins.
#
# We then modify the histogram to allow for ***plt.xlabel('')/plt.ylabel(''), plt.title(''), plt.legend(''), and plt.xticks(range(,))***.
#
#
# ***plt.show*** prints the completed histogram!

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 1</b>
#
#
#
#
# You've plotted an excellent chart — it's clear, has a title, labeled axes, and a legend.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️
#
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
#
# However, please make sure to use parentheses after `.show()` so that the chart displays as expected - this comment is also relevant for the following charts.
#
# ---
#
#
# Also, don’t forget to answer the question stated in the section header:
# **What is the difference in distribution?**

# %% [markdown]
# ### [B2] What's the distribution for the number of orders per customer?

# %%
num_customer_orders = orders['user_id'].value_counts().sort_index()

plt.figure(figsize=(10,5))
plt.hist(num_customer_orders, bins = 15, edgecolor='black')
plt.title('Distribution of Orders per Customer')
plt.xlabel('Number of Orders')
plt.ylabel('Number of Customers')


plt.show

print("""
The histogram shows most customers place 4 orders or less. There is a 
negative slope and steep drops between the first 4 bins, indicating frequent but irregular
habits. There is a long and narrow tail, showing there some frequent instacart users,
but no where near as many as the first 4 bins. 

The data indicates there is a large opporunity to convert some infrequent irregular users into
regularly returning customers.
""")
# Out:
# The histogram shows most customers place 4 orders or less. There is a
# negative slope and steep drops between the first 4 bins, indicating frequent but irregular
# habits. There is a long and narrow tail, showing there some frequent instacart users,
# but no where near as many as the first 4 bins.
#
# The data indicates there is a large opporunity to convert some infrequent irregular users into
# regularly returning customers.

# %% [markdown]
# Using .value_counts().sort_index(), "num_customer_orders" is created to count the number of orders by user_id. user_id is sorted for convenience.
#
# We then adjusted the histogram size (plt.figure(figsize=()));
#     introduced data for histogram @ plt.hist() (bins & edgecolor established);
#     histogram titled @ plt.title('');
#     x-axis labeled @ plt.xlabel;
#     y-axis labeled @ plt.ylabel;
#     histogram printed @ plt.show

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️ Yes, indeed - it appears that most customers have up to four orders.
#
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# Thank you for taking the time to describe your steps — it shows your engagement with the process.
# Since the code is already visible in the notebook, you don’t need to explain which functions you used to create the chart.
#
# Instead, try to focus more on interpreting the results.
# Please make sure to answer the specific questions mentioned in the section headers — that will help demonstrate your analytical thinking and ensure the analysis is complete.

# %% [markdown]
# ### [B3] What are the top 20 popular products (display their id and name)?

# %%
top_20_count = order_products['product_id'].value_counts().head(20) 

top_20_products_df = top_20_count.reset_index()

top_20_products_df.columns = ['product_id', 'order_count']

top_20_products_named = top_20_products_df.merge(products, on='product_id')

print(top_20_products_named[['product_id', 'product_name']])
# Out:
#     product_id              product_name
# 0        24852                    banana
# 1        13176    bag of organic bananas
# 2        21137      organic strawberries
# 3        21903      organic baby spinach
# 4        47209      organic hass avocado
# 5        47766           organic avocado
# 6        47626               large lemon
# 7        16797              strawberries
# 8        26209                     limes
# 9        27845        organic whole milk
# 10       27966       organic raspberries
# 11       22935      organic yellow onion
# 12       24964            organic garlic
# 13       45007          organic zucchini
# 14       39275       organic blueberries
# 15       49683            cucumber kirby
# 16       28204        organic fuji apple
# 17        5876             organic lemon
# 18        8277  apple honeycrisp organic
# 19       40706    organic grape tomatoes

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# ✔️ Great job - this is the correct list.
#
#
#
#
# <div class="alert alert-danger"; style="border-left: 7px solid red">
# <b>⛔️ Reviewer's comment, v. 1</b>
#
# It looks like you're using the `products` dataframe here, but keep in mind that it serves more as a dictionary of products — it doesn't contain sales data.
#
# To find the most popular products (i.e., those purchased most often), you'll need to merge it with the `order_products` dataframe, where the actual purchase records are stored.
#
# Please update your code accordingly so the analysis reflects the correct data source.

# %% [markdown]
# I've printed a df with the top 20 games in descending order, beginning with 0.
#
# I used .value_counts() on products['product_id'] to get the top 20 through .head().
#
# I assigned this series to a new variable/df. .columns wa sused then to rename columns to better describe their content.
#
# Finally, I created a new df using .merge() on top_20_products_df and products; merged on shared 'product_id' column.
#
# To see the results, we printed product_id and product_name from the merged df showing top 20 products in descending order.

# %% [markdown]
# # [C] Hard (must complete at least two to pass)

# %% [markdown]
# ### [C1] How many items do people typically buy in one order? What does the distribution look like?

# %%
items_per_order = order_products['order_id'].value_counts()

plt.figure(figsize = (10,5))

plt.hist(items_per_order, bins = 30, edgecolor='black')
plt.title('Distribution of Items per Order')
plt.xlabel('Number of Items')
plt.ylabel('Number of Orders')

plt.show()

print(items_per_order.describe())

print("""
Most number of items in orders are between 1 - 20. The histogram is right skewed, indicating a 
preference for low to mid number of items per order. 
""")
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: order_id, dtype: float64
#
# Most number of items in orders are between 1 - 20. The histogram is right skewed, indicating a
# preference for low to mid number of items per order.

# %% [markdown]
# For this task, i relied on counting the occurances of each 'order_id' to surmise the total number of items (x) per order (y). I did this using .value_counts() on order_products['order_id'] and assigning it to items_per_order. I then used plt to plot the distribution as a histogram.
#
# .describe() is also used for further assesments re:distribution.

# %% [markdown]
# ### [C2] What are the top 20 items that are reordered most frequently (display their names and product IDs)?

# %%
top_20_reordered = (
    order_products.groupby('product_id')['reordered'].sum()
    .sort_values(ascending=False)
    .head(20)
    .reset_index()
)

top_20_reordered = top_20_reordered.merge(products[['product_id', 'product_name']], on='product_id')

print(top_20_reordered)
# Out:
#     product_id  reordered              product_name
# 0        24852      55763                    banana
# 1        13176      44450    bag of organic bananas
# 2        21137      28639      organic strawberries
# 3        21903      26233      organic baby spinach
# 4        47209      23629      organic hass avocado
# 5        47766      18743           organic avocado
# 6        27845      16251        organic whole milk
# 7        47626      15044               large lemon
# 8        27966      14748       organic raspberries
# 9        16797      13945              strawberries
# 10       26209      13327                     limes
# 11       22935      11145      organic yellow onion
# 12       24964      10411            organic garlic
# 13       45007      10076          organic zucchini
# 14       49683       9538            cucumber kirby
# 15       28204       8989        organic fuji apple
# 16        8277       8836  apple honeycrisp organic
# ...

# %% [markdown]
# To obtain a list of the top 20 items that are reordered most frequently
# (and display their names and product IDs), I had to create a new df; this time I used groupby().sum() on order_products.groupby('product_id')['reordered'].
#
# This is to group 'product_id' of order_products and count the number of 'reordered' by calling .sum() on the groupby().
#
# .sort_values(ascending=False) sorts the df in descending order.
#
# .head(20) returns the first 20 rows.
#
# .reset_index resets index for a more cohesive reading experience.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 1</b>
#
# This is the correct list of most popular reorders.

# %% [markdown]
# <div class="alert alert-success" style="border-left: 7px solid green">
# <b>✅ Reviewer's Comment, v. 1</b>
#
# Excellent job on this section! You've demonstrated a clear understanding of the data and applied the necessary techniques thoughtfully.
# Your code is well-structured and easy to follow, and your visualizations are informative and clearly labeled.
# Most importantly, your interpretations show that you're not just processing the data but also thinking critically about what it means.
#
# Keep up the great work — you're building a strong foundation for your analytical skills!
# </div>

# %% [markdown]
# ### [C3] For each product, what proportion of its orders are reorders?

# %% [markdown]
# ### [C4] For each customer, what proportion of their products ordered are reorders?

# %% [markdown]
# ### [C5] What are the top 20 items that people put in their carts first?

# %% [markdown]
# **Conclusion**
#
# After importing relevant files onto Jupyter for data processing, we begin our analysis into Instacart customer actions. Main results from analysis are provided below:
#
# [A1]: 'order_hour_of_day' and 'order_dow' values in the orders tables are sensible (i.e. 'order_hour_of_day' ranges from 0 to 23 and 'order_dow' ranges from 0 to 6).
#
# [A2]: Most people order between 9 and 16 (4 PM)). The bar is left-skewed– the least amount of customers order between the hours of 0 - 5. Most ordered at hours 7 - 20.
#
# [A3]: There is a noticable range between the Max and Min of the order distribution of about 2,000
# orders between Sunday (Max) and Thursday (Min). The chart is right-skewed; there is a slight
# surge between Thursday and Friday. Nonetheless, the overall distribution remains consistently above 55,000.
#
# [A4]: The average/mean wait-time is about 11 days, while the 50 percentile lands at 7 days. The top 3 days for total elapsed days since previous order are 30, 7, and 6.
#
# [B1]: The differences between both days are nuanced except for hours 11 through 14,
# where we see a transparent gap indicating a larger than normal discrepancy.
#
# [B2]: The histogram shows most customers place 4 orders or less. There is a
# negative slope and steep drops between the first 4 bins, indicating frequent but irregular
# habits. There is a long and narrow tail, showing there some frequent instacart users,
# but no where near as many as the first 4 bins.
#
# [B3]: Top 20 products are rendered and presented; Top 3 products are "banana," "bag of organic bananas," and "organic strawberries."
#
# [C1]: Most number of items in orders are between 1 - 20. The histogram is right skewed, indicating a preference for low to mid number of items per order.
#
# [C2]: Top 20 items that are reordered most frequently are provided. Top 3 products are
# 24852-banana, 13176-bag of organic bananas, 21137-organic strawberries.

# %% [markdown]
# <div class="alert alert-success"; style="border-left: 7px solid green">
# <b>✅ Reviewer's comment, v. 2</b>
#
# Excellent work—you’ve summarized all the major insights clearly and effectively.
#
#
#
#
#
# <div class="alert alert-warning"; style="border-left: 7px solid gold">
# <b>⚠️ Reviewer's comment, v. 1</b>
#
# The project will look more complete and professional if you add a conclusion summarising the main results of the analysis?
